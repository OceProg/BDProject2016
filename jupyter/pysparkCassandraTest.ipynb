# %%
import pandas as pd
import itertools

# %%
def open_with_pandas_read_csv(filename):
    df = pd.read_csv(filename, sep=",", nrows=1000                                                                                                                                                                                                                             )
    header = df.columns.values
    data = df.values
    return df, header, data

#Files
path = "/home/user14/Documents/projet/data/"
file1 = "train.csv"


#Inputs
#train_np = open_with_numpy_loadtxt(path+file1)
train_df, train_header, train_data = open_with_pandas_read_csv(path+file1)

# %%
x, y = train_df.X, train_df.Y

# %%
for x, y in zip(train_df.X, train_df.Y):
    print x, y
# Out:
#  -122.425891675 37.7745985957
# -122.425891675 37.7745985957
# -122.424363021 37.800414322
# -122.426995327 37.8008726328
# -122.438737623 37.7715411721
# -122.403252361 37.7134307041
# -122.423326977 37.7251380404
# -122.371274317 37.727564072
# -122.508194031 37.7766012607
# -122.419087677 37.8078015517
# -122.419087677 37.8078015517
# -122.487983073 37.7376666543
# -122.412414264 37.7830037965
# -122.432914603 37.7843533427
# -122.397744427 37.7299346936
# -122.383691504 37.743189042
# -122.412597377 37.7839320277
# -122.421681532 37.7428222005
# -122.38640087 37.7389834911
# -122.412249768 37.7825563302
# -122.449389111 37.7426688026
# -122.420272135 37.7473316299
# -122.412249768 37.7825563302
# -122.412249768 37.7825563302
# -122.436049204 37.7998412229
# -122.410509259 37.7860432223
# -122.431017557 37.7873880712
# -122.423656343 37.7325564882
# -122.475773498 37.7449190696
# -122.499787121 37.7485176035
# -122.431046366 37.7830295716
# -122.4351501 37.7617597244
# ...

# %%
x = list(train_df.X)
print type(x)
# Out:
# <type 'list'>
